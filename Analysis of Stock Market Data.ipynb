# %%
import datetime
import warnings

# %%
import yfinance as yf
from hmmlearn.hmm import GaussianHMM
import datetime

# 1. Define your parameters
ticker = "AAPL"
start_date = "2020-01-01"
end_date = "2023-12-31"

# 2. Replace quotes_historical_yahoo_och1 with this:
data = yf.download(ticker, start=start_date, end=end_date)

# 3. Prepare the data for GaussianHMM
# Usually, HMMs in finance use log returns or close prices
# This extracts the 'Close' prices as a 2D array for hmmlearn
X = data['Close'].values.reshape(-1, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19004\1214493612.py in <module>
# ----> 1 import yfinance as yf
#       2 from hmmlearn.hmm import GaussianHMM
#       3 import datetime
#       4
#       5 # 1. Define your parameters
#
# ~\anaconda4\lib\site-packages\yfinance\__init__.py in <module>
#      24 from .lookup import Lookup
#      25 from .ticker import Ticker
# ---> 26 from .calendars import Calendars
#      27 from .tickers import Tickers
#      28 from .multi import download
#
# ~\anaconda4\lib\site-packages\yfinance\calendars.py in <module>
#      14
#      15
# ---> 16 class CalendarQuery:
#      17     """
#      18     Simple CalendarQuery class for calendar queries, similar to yf.screener.query.QueryBase.
#
# ~\anaconda4\lib\site-packages\yfinance\calendars.py in CalendarQuery()
#      31     """
#      32
# ...
